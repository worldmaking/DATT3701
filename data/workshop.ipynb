# %% [markdown]
# # Data Analyst Workshop

# %% [markdown]
# In this short workshop I will go over the basics of data analysis in Python in order for you to be able to analyze and plot some of the data you will be exporting from Unity
# In this workshop we will go over the following:
#
# 1. installing and using Juypter notebook
# 2. importing and creating data frames using pandas
# 3. cleaning data
# 4. basic data analysis
# 5. data plotting
# 6. exporting your data frame

# %% [markdown]
# ## Juypter notebook

# %% [markdown]
# The Jupyter Notebook is an open-source web application that allows you to create and share documents that contain live code, equations, visualizations and narrative text. Uses include: data cleaning and transformation, numerical simulation, statistical modeling, data visualization, machine learning, and much more.

# %% [markdown]
# #### How to install

# %% [markdown]
# Download Anaconda while will allow you to use Jupyter notebook and all the libraries you will need for data analysis and machine learning
# you can download it from: https://www.anaconda.com/distribution/

# %% [markdown]
# #### The basics of Jupyter Notebook

# %% [markdown]
# Once you have it install you can open Jupyet Notebook by running the app from Anaconda, or using the shortcut created by the program. you can also run it directly from the commend (or cmd) line in your computer by simply writing *jupyter notebook* in the prompt window
#
# for more information about it and alternative ways to install and run it check out: https://www.datacamp.com/community/tutorials/tutorial-jupyter-notebook

# %% [markdown]
# ##### Working With The Notebook
# The notebook itself consists of cells. A first empty cell is already available after having created the new notebook, there are a two types of cells- code and markdown

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# This is a markdown cell- it allows us to write and format text. it uses Markdown language, which allows us to have some simple formatting, for example:
# # H1
# ## H2
# ### H3
# #### H4
# ##### H5
# ###### H6
#
# Emphasis, aka italics, with *asterisks* or _underscores_.
#
# Strong emphasis, aka bold, with **asterisks** or __underscores__.
#
# Combined emphasis with **asterisks and _underscores_**.
#
# Strikethrough uses two tildes. ~~Scratch this.~~
#
#
# you can read all about it at: https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet#lists

# %% [markdown]
# ---

# %% [markdown]
# You can change the cell type from Code to Markdown to include explanatory text in your notebook. To change the type you can use the dropdown input control or **M** will transform the active cell to a Markdown cell, **Y** will set the active cell to a code cell.
#
# To run a cell use **ctrl+Enter** (or press the run button) **shift+enter** will run the cell but also open up a new one
#
#
# Once in command mode:
#
# Scroll up and down your cells with your Up and Down keys.
#
# Press **A** or **B** to insert a new cell above or below the active cell.
#
# **D + D** (D twice) will delete the active cell.
#
# **Z** will undo cell deletion.
#
# Hold Shift and press Up or Down to select multiple cells at once.
#
# With multple cells selected, **Shift + M** will merge your selection.
#
# **Ctrl + Shift + -**, in edit mode, will split the active cell at the cursor.
#
# You can also click and **Shift + Click** in the margin to the left of your cells to select them.

# %% [markdown]
# ## Importing and creating dataframes

# %% [markdown]
# For this workshop we will be using a few data science libraries which will allow us to import data frames, clean and organize them (according to the data we want) them and create a visualization of the data. note: I will not get into statistics or machine learning, as it is a bit more complex for the time we have but I hope that in the end of this workshop you will have some idea how to approach data analysis
#
# first thing first, we need to import the libraries we will be using

# %%
import pandas as pd #dataframes
import numpy as np #number series
import matplotlib.pyplot as plt #plotting
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Importing files into dataframes

# %% [markdown]
# #### csv
# pd.read_csv('example')
#
# #### File from URL
# pd.read_csv("http://winterolympicsmedals.com/medals.csv")
#
# #### .txt
#
# pd.read_table(".txt")
#
# #### Excel
#
# pd.read_excel('.xlsx',sheet_name='Sheet1')
#
# #### HTML
# pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
# I will be using a data set from the titanic that I downloaded as an excel file 
df = pd.read_excel("titanic3.xls",sheet_name="titanic3")

# %%
#now lets see what is in the database

df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
#The data frame columns
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
#Summary statisticts of each (numeric) column:
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# ## Cleaning data

# %% [markdown]
# One of the main thing we want to do when we have a new data sets is to clean the data and organize it for analysis, you will not always need all of the methods but I will show you the main ones

# %% [markdown]
# #### Selection and Indexing
#
# Let's learn the various methods to grab data from a DataFrame

# %%
df['fare']
# Out:
# 0       211.3375
# 1       151.5500
# 2       151.5500
# 3       151.5500
# 4       151.5500
# 5        26.5500
# 6        77.9583
# 7         0.0000
# 8        51.4792
# 9        49.5042
# 10      227.5250
# 11      227.5250
# 12       69.3000
# 13       78.8500
# 14       30.0000
# 15       25.9250
# 16      247.5208
# 17      247.5208
# 18       76.2917
# 19       75.2417
# 20       52.5542
# 21       52.5542
# 22       30.0000
# 23      227.5250
# 24      221.7792
# 25       26.0000
# 26       91.0792
# 27       91.0792
# 28      135.6333
# 29       26.5500
#           ...
# 1279      7.8542
# 1280      7.8958
# 1281      9.0000
# 1282      8.0500
# 1283      7.5500
# 1284      8.0500
# 1285      9.5000
# 1286      7.2292
# 1287      7.7500
# 1288      6.4958
# 1289      6.4958
# 1290      7.0000
# 1291      8.7125
# 1292      7.5500
# 1293      8.0500
# 1294     16.1000
# 1295      7.2500
# 1296      8.6625
# 1297      7.2500
# 1298      9.5000
# 1299     14.4542
# ...

# %%
# Pass a list of column names
df[['fare','survived']]
# Out:
#           fare  survived
# 0     211.3375         1
# 1     151.5500         1
# 2     151.5500         0
# 3     151.5500         0
# 4     151.5500         0
# 5      26.5500         1
# 6      77.9583         1
# 7       0.0000         0
# 8      51.4792         1
# 9      49.5042         0
# 10    227.5250         0
# 11    227.5250         1
# 12     69.3000         1
# 13     78.8500         1
# 14     30.0000         1
# 15     25.9250         0
# 16    247.5208         0
# 17    247.5208         1
# 18     76.2917         1
# 19     75.2417         0
# 20     52.5542         1
# 21     52.5542         1
# 22     30.0000         1
# 23    227.5250         1
# 24    221.7792         1
# 25     26.0000         0
# 26     91.0792         1
# 27     91.0792         1
# 28    135.6333         1
# 29     26.5500         1
# ...        ...       ...
# 1279    7.8542         0
# 1280    7.8958         0
# 1281    9.0000         0
# 1282    8.0500         0
# 1283    7.5500         0
# ...

# %% [markdown]
# **Creating a new column:**

# %%
df['new'] = df['fare'] + df['survived']

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest       new
# ...

# %% [markdown]
# ** Removing Columns**

# %%
df = df.drop('new',axis=1)

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# ** Selecting Rows**

# %%
#select based off label
df.loc[1]
# Out:
# pclass                                     1
# survived                                   1
# name          Allison, Master. Hudson Trevor
# sex                                     male
# age                                   0.9167
# sibsp                                      1
# parch                                      2
# ticket                                113781
# fare                                  151.55
# cabin                                C22 C26
# embarked                                   S
# boat                                      11
# body                                     NaN
# home.dest    Montreal, PQ / Chesterville, ON
# Name: 1, dtype: object

# %%
#select based off position 
df.iloc[1]
# Out:
# pclass                                     1
# survived                                   1
# name          Allison, Master. Hudson Trevor
# sex                                     male
# age                                   0.9167
# sibsp                                      1
# parch                                      2
# ticket                                113781
# fare                                  151.55
# cabin                                C22 C26
# embarked                                   S
# boat                                      11
# body                                     NaN
# home.dest    Montreal, PQ / Chesterville, ON
# Name: 1, dtype: object

# %% [markdown]
# ** Selecting subset of rows and columns **

# %%
df.iloc[2,3]
# Out:
# 'female'

# %%
df.iloc[[1,2],[2,3]]
# Out:
#                              name     sex
# 1  Allison, Master. Hudson Trevor    male
# 2    Allison, Miss. Helen Loraine  female

# %% [markdown]
# ### Missing Data

# %%
df2 = pd.DataFrame({'A':[1,2,np.nan],
                  'B':[5,np.nan,np.nan],
                  'C':[1,2,3]})

# %%
df2
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df2.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df2.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df2.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
df2.fillna(value='FILL VALUE')
# Out:
#             A           B  C
# 0           1           5  1
# 1           2  FILL VALUE  2
# 2  FILL VALUE  FILL VALUE  3

# %%
Clean = df.fillna(value='0')

# %%
Clean.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket     fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.338       B5        S    2    0
# 1  0.9167      1      2  113781   151.55  C22 C26        S   11    0
# 2       2      1      2  113781   151.55  C22 C26        S    0    0
# 3      30      1      2  113781   151.55  C22 C26        S    0  135
# 4      25      1      2  113781   151.55  C22 C26        S    0    0
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
##Find Null Values or Check for Null Values
df.isnull().head()
# Out:
#    pclass  survived   name    sex    age  sibsp  parch  ticket   fare  cabin  \
# 0   False     False  False  False  False  False  False   False  False  False
# 1   False     False  False  False  False  False  False   False  False  False
# 2   False     False  False  False  False  False  False   False  False  False
# 3   False     False  False  False  False  False  False   False  False  False
# 4   False     False  False  False  False  False  False   False  False  False
#
#    embarked   boat   body  home.dest
# 0     False  False   True      False
# 1     False  False   True      False
# 2     False   True   True      False
# 3     False   True  False      False
# 4     False   True   True      False

# %% [markdown]
# #### Merging, Joining, and Concatenating
#
# There are 3 main ways of combining DataFrames together: Merging, Joining and Concatenating.

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %% [markdown]
# **Concatenation**
#
# Concatenation basically glues together DataFrames.

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %% [markdown]
# **Merge**
#
# The function allows you to merge DataFrames together

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
pd.merge(left,right,how='inner',on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
pd.merge(left, right, on=['key1', 'key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
pd.merge(left, right, how='outer', on=['key1', 'key2'])
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K1   A3   B3  NaN  NaN
# 5   K2   K0  NaN  NaN   C3   D3

# %%
pd.merge(left, right, how='right', on=['key1', 'key2'])
# Out:
#   key1 key2    A    B   C   D
# 0   K0   K0   A0   B0  C0  D0
# 1   K1   K0   A2   B2  C1  D1
# 2   K1   K0   A2   B2  C2  D2
# 3   K2   K0  NaN  NaN  C3  D3

# %%
pd.merge(left, right, how='left', on=['key1', 'key2'])
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %% [markdown]
# ** Joining **
#
# Joining is a convenient method for combining the columns of two potentially differently-indexed DataFrames into a single result DataFrame.

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
left.join(right)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
left.join(right, how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %% [markdown]
# information about inner/outer join http://www.datamartist.com/sql-inner-join-left-outer-join-full-outer-join-examples-with-syntax-for-sql-server

# %% [markdown]
# #### Dummy Variables

# %% [markdown]
# Sometimes, you need to convert text variables into a number, for that you will need to make dummy number

# %%
#lets change the gender into 0,1 with 0 being male and 1 being female

Clean['Sex_num'] = Clean.sex.map({'female':0, 'male':1})

# %%
Clean.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket     fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.338       B5        S    2    0
# 1  0.9167      1      2  113781   151.55  C22 C26        S   11    0
# 2       2      1      2  113781   151.55  C22 C26        S    0    0
# 3      30      1      2  113781   151.55  C22 C26        S    0  135
# 4      25      1      2  113781   151.55  C22 C26        S    0    0
#
#                          home.dest  Sex_num
# ...

# %%
new_df = Clean.drop('sex',axis=1)

# %%
new_df
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %% [markdown]
# ## Basic data analysis

# %% [markdown]
# As I mentioned before we won't have time to do more complex analysis like statistical analysis, but here are some basic operations you can do

# %% [markdown]
# ### Querying Data with Conditions.
#
# All of the selection we've done up until this point has been by row or column label.  What if we wanted to find out which parts of our data set satisfy a specific condition?  There are a number of ways to do this that yield different-looking results:
# 1. Using the syntax ```df[conditions]```, Pandas will return a subset of the dataframe that matches the condition given.
# 2. Using the ```.where()``` command, Pandas will return an object the same dimensions as the original, but will fill in everything that doesn't fit the criteria with a value of your choice.

# %%
new_df.head()
# Out:
#    pclass  survived                                             name     age  \
# 0       1         1                    Allen, Miss. Elisabeth Walton      29
# 1       1         1                   Allison, Master. Hudson Trevor  0.9167
# 2       1         0                     Allison, Miss. Helen Loraine       2
# 3       1         0             Allison, Mr. Hudson Joshua Creighton      30
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)      25
#
#    sibsp  parch  ticket     fare    cabin embarked boat body  \
# 0      0      0   24160  211.338       B5        S    2    0
# 1      1      2  113781   151.55  C22 C26        S   11    0
# 2      1      2  113781   151.55  C22 C26        S    0    0
# 3      1      2  113781   151.55  C22 C26        S    0  135
# 4      1      2  113781   151.55  C22 C26        S    0    0
#
#                          home.dest  Sex_num
# 0                     St Louis, MO        0
# 1  Montreal, PQ / Chesterville, ON        1
# ...

# %%
#we will start will looking at just the tickets who cost less then 5
new_df[df['fare']< 5]
# Out:
#       pclass  survived                                   name age  sibsp  \
# 7          1         0                 Andrews, Mr. Thomas Jr  39      0
# 70         1         0  Chisholm, Mr. Roderick Robert Crispin   0      0
# 125        1         0                       Fry, Mr. Richard   0      0
# 150        1         0                  Harrison, Mr. William  40      0
# 170        1         1                Ismay, Mr. Joseph Bruce  49      0
# 223        1         0          Parr, Mr. William Henry Marsh   0      0
# 234        1         0        Reuchlin, Jonkheer. John George  38      0
# 363        2         0                  Campbell, Mr. William   0      0
# 384        2         0         Cunningham, Mr. Alfred Fleming   0      0
# 410        2         0       Frost, Mr. Anthony Wood "Archie"   0      0
# 473        2         0                   Knight, Mr. Robert J   0      0
# 528        2         0            Parkes, Mr. Francis "Frank"   0      0
# ...

# %%
#now (for example) lets look at all the folks who survived and paid less then 10
new_df[(df['fare']< 10) & (df['survived']==1)]
# Out:
#       pclass  survived                                             name  \
# 170        1         1                          Ismay, Mr. Joseph Bruce
# 604        3         1                      Abelseth, Miss. Karen Marie
# 605        3         1                    Abelseth, Mr. Olaus Jorgensen
# 606        3         1         Abrahamsson, Mr. Abraham August Johannes
# 607        3         1        Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 611        3         1                        Aks, Master. Philip Frank
# 612        3         1                       Aks, Mrs. Sam (Leah Rosen)
# 621        3         1  Andersen-Jensen, Miss. Carla Christine Nielsine
# 625        3         1                  Andersson, Miss. Erna Alexandra
# 630        3         1     Andersson, Mr. August Edvard ("Wennerstrom")
# 645        3         1                       Asplund, Mr. Johan Charles
# 647        3         1            Assaf Khalil, Mrs. Mariana ("Miriam")
# ...

# %%
#simlar thing, but lets check how many of those survived where female
new_df[(df['sex'] == 'female') & (df['survived']==1)]
# Out:
#       pclass  survived                                               name age  \
# 0          1         1                      Allen, Miss. Elisabeth Walton  29
# 6          1         1                  Andrews, Miss. Kornelia Theodosia  63
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)  53
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  18
# 12         1         1                      Aubart, Mme. Leontine Pauline  24
# 13         1         1                       Barber, Miss. Ellen "Nellie"  26
# 17         1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  50
# 18         1         1                              Bazzani, Miss. Albina  32
# 21         1         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47
# 23         1         1                              Bidois, Miss. Rosalie  42
# 24         1         1                                  Bird, Miss. Ellen  29
# ...

# %%
#simlar thing, but lets check how many of those survived where male
new_df[(df['sex'] == 'male') & (df['survived']==1)].count()
# Out:
# pclass       161
# survived     161
# name         161
# age          161
# sibsp        161
# parch        161
# ticket       161
# fare         161
# cabin        161
# embarked     161
# boat         161
# body         161
# home.dest    161
# Sex_num      161
# dtype: int64

# %% [markdown]
# Another option for querying is using Pandas' ```.where()``` command.  It has the syntax<br>
# ``` df.where(condition, what to fill with where condition is false)```<br>
# If you do not put a "what to fill" value in, it will default to replacing the False values of the condition to np.NaN.

# %%
NewYork = new_df.where(df['home.dest'] == 'New York, NY')

# %%
NewYork.head(10)
# Out:
#    pclass  survived                 name  age  sibsp  parch ticket   fare  \
# 0     NaN       NaN                  NaN  NaN    NaN    NaN    NaN    NaN
# 1     NaN       NaN                  NaN  NaN    NaN    NaN    NaN    NaN
# 2     NaN       NaN                  NaN  NaN    NaN    NaN    NaN    NaN
# 3     NaN       NaN                  NaN  NaN    NaN    NaN    NaN    NaN
# 4     NaN       NaN                  NaN  NaN    NaN    NaN    NaN    NaN
# 5     1.0       1.0  Anderson, Mr. Harry   48    0.0    0.0  19952  26.55
# 6     NaN       NaN                  NaN  NaN    NaN    NaN    NaN    NaN
# 7     NaN       NaN                  NaN  NaN    NaN    NaN    NaN    NaN
# 8     NaN       NaN                  NaN  NaN    NaN    NaN    NaN    NaN
# 9     NaN       NaN                  NaN  NaN    NaN    NaN    NaN    NaN
#
#   cabin embarked boat body     home.dest  Sex_num
# 0   NaN      NaN  NaN  NaN           NaN      NaN
# 1   NaN      NaN  NaN  NaN           NaN      NaN
# ...

# %%
NewYork.count()
# Out:
# pclass       64
# survived     64
# name         64
# age          64
# sibsp        64
# parch        64
# ticket       64
# fare         64
# cabin        64
# embarked     64
# boat         64
# body         64
# home.dest    64
# Sex_num      64
# dtype: int64

# %% [markdown]
# ### Aggregated Functions

# %% [markdown]
# those are all kind of functions which will allow you some simple analysis with the data. once you write the database and press the tab it will give you some of the possible options

# %%
new_df['pclass'].count()
# Out:
# 1309

# %%
df['fare'].max()
# Out:
# 512.3292

# %%
df['fare'].min()
# Out:
# 0.0

# %%
new_df['fare'].unique()
# Out:
# array([211.3375, 151.55, 26.55, 77.9583, 0.0, 51.4792, 49.5042, 227.525,
#        69.3, 78.85, 30.0, 25.925, 247.5208, 76.2917, 75.2417, 52.5542,
#        221.7792, 26.0, 91.0792, 135.6333, 35.5, 31.0, 164.8667, 262.375,
#        55.0, 30.5, 50.4958, 39.6, 27.7208, 134.5, 26.2875, 27.4458,
#        512.3292, 5.0, 47.1, 120.0, 61.175, 53.1, 86.5, 29.7, 136.7792,
#        52.0, 25.5875, 83.1583, 25.7, 71.0, 71.2833, 57.0, 81.8583,
#        106.425, 56.9292, 78.2667, 31.6792, 31.6833, 110.8833, 26.3875,
#        27.75, 263.0, 133.65, 49.5, 79.2, 38.5, 211.5, 59.4, 89.1042,
#        34.6542, 28.5, 153.4625, 63.3583, 55.4417, 76.7292, 42.4, 83.475,
#        93.5, 42.5, 51.8625, 50.0, 57.9792, 90.0, 30.6958, 80.0, 28.7125,
#        25.9292, 39.4, 45.5, 146.5208, 82.1708, 57.75, 113.275, 26.2833,
#        108.9, 25.7417, 61.9792, 66.6, 40.125, 55.9, 60.0, 82.2667,
#        32.3208, 79.65, 28.5375, 33.5, 34.0208, 75.25, 77.2875, 61.3792,
# ...

# %%
new_df['fare'].nunique()
# Out:
# 282

# %%
#How many entries are for
new_df['fare'].value_counts()
# Out:
# 8.0500     60
# 13.0000    59
# 7.7500     55
# 26.0000    50
# 7.8958     49
# 10.5000    35
# 7.7750     26
# 7.2292     24
# 7.9250     23
# 26.5500    22
# 8.6625     21
# 7.2250     21
# 7.8542     21
# 7.2500     18
# 0.0000     17
# 21.0000    14
# 16.1000    12
# 9.5000     12
# 27.7208    11
# 69.5500    11
# 14.5000    11
# 15.5000    10
# 7.8792     10
# 7.7958     10
# 14.4542    10
# 7.0500      9
# 15.2458     9
# 24.1500     9
# 7.5500      8
# 46.9000     8
#            ..
# 12.6500     1
# 8.3000      1
# 15.0500     1
# 8.4042      1
# 15.0333     1
# 9.3250      1
# 25.7000     1
# 7.8000      1
# 8.6542      1
# 4.0125      1
# 7.1417      1
# 10.7083     1
# 26.2833     1
# 7.2833      1
# 45.5000     1
# 25.7417     1
# 49.5000     1
# 7.7208      1
# 35.0000     1
# 34.0208     1
# 7.7875      1
# 31.6792     1
# 9.4833      1
# 9.8375      1
# 7.8750      1
# 8.9625      1
# 28.7125     1
# 27.4458     1
# 8.4583      1
# 7.7417      1
# ...

# %%
# %%html
# <style>
#     table {
#         display: inline-block
#     }
# </style>
# Out:
# <style>
#     table {
#         display: inline-block
#     }
# </style>

# %% [markdown]
# | Function | Description                         |
# |----------|-------------------------------------|
# | count    | Number of non-null observations     |
# | sum      | Sum of values                       |
# | mean     | Mean of values                      |
# | mad      | Mean absolute deviation             |
# | median   | Arithmetic median of values         |
# | min      | Minimum                             |
# | max      | Maximum                             |
# | mode     | Mode                                |
# | abs      | Absolute Value                      |
# | prod     | Product of values                   |
# | std      | Unbiased standard deviation         |
# | var      | Unbiased variance                   |
# | sem      | Unbiased standard error of the mean |
# | skew     | Unbiased skewness (3rd moment)      |
# | kurt     | Unbiased kurtosis (4th moment)      |
# | quantile | Sample quantile (value at %)        |
# | cumsum   | Cumulative sum                      |
# | cumprod  | Cumulative product                  |
# | cummax   | Cumulative maximum                  |
# | cummin   | Cumulative minimum                  |

# %% [markdown]
# ### Groupby

# %%
# you can use the .groupby() method to group rows together based off of a column name

su = new_df.groupby('survived')

# %%
#And then call aggregate methods off the object:
su.mean()
# Out:
#             pclass     sibsp     parch   Sex_num
# survived
# 0         2.500618  0.521632  0.328801  0.843016
# 1         1.962000  0.462000  0.476000  0.322000

# %%
su.std()
# Out:
#             pclass     sibsp     parch   Sex_num
# survived
# 0         0.744825  1.210449  0.912332  0.364011
# 1         0.872972  0.685197  0.776292  0.467711

# %%
su.min()
# Out:
#           pclass                              name  sibsp  parch cabin  \
# survived
# 0              1               Abbing, Mr. Anthony      0      0     0
# 1              1  Abbott, Mrs. Stanton (Rosa Hunt)      0      0     0
#
#          embarked home.dest  Sex_num
# survived
# 0               C         0        0
# 1               0         0        0

# %%
su.max()
# Out:
#           pclass                                           name  sibsp  parch  \
# survived
# 0              3                    van Melkebeke, Mr. Philemon      8      9
# 1              3  del Carlo, Mrs. Sebastiano (Argenia Genovesi)      4      5
#
#          cabin embarked            home.dest  Sex_num
# survived
# 0            T        S       Youngstown, OH        1
# 1           G6        S  Zurich, Switzerland        1

# %%
su.count()
# Out:
#           pclass  name  age  sibsp  parch  ticket  fare  cabin  embarked  \
# survived
# 0            809   809  809    809    809     809   809    809       809
# 1            500   500  500    500    500     500   500    500       500
#
#           boat  body  home.dest  Sex_num
# survived
# 0          809   809        809      809
# 1          500   500        500      500

# %%
su.describe()
# Out:
#          Sex_num                                               parch  \
#            count      mean       std  min  25%  50%  75%  max  count
# survived
# 0          809.0  0.843016  0.364011  0.0  1.0  1.0  1.0  1.0  809.0
# 1          500.0  0.322000  0.467711  0.0  0.0  0.0  1.0  1.0  500.0
#
#                    ...  pclass       sibsp                                     \
#               mean ...     75%  max  count      mean       std  min  25%  50%
# survived           ...
# 0         0.328801 ...     3.0  3.0  809.0  0.521632  1.210449  0.0  0.0  0.0
# 1         0.476000 ...     3.0  3.0  500.0  0.462000  0.685197  0.0  0.0  0.0
#
#
#           75%  max
# survived
# 0         1.0  8.0
# 1         1.0  4.0
#
# [2 rows x 32 columns]

# %% [markdown]
# ## Data plotting

# %% [markdown]
# One of the great things about Jupyter Notebook is that it allows you to use visuals (like graph) in the notebook itself. There are a few different libraries you can use but we will use matplotlib as it is very simple to use

# %%
pylab.rcParams['figure.figsize'] = (12.0, 10.0) #setting figure size

# %%
df_short = new_df.head(20)

# %%
df_short2 = df.head(20)

# %%
df_short
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %% [markdown]
# **Lets start with a simple line plot**

# %%
df_short.plot();

# %%
df_short['fare'].plot();

# %%
#we can change the look
df_short['fare'].plot(title='fare price',legend=True, color='pink')

# %% [markdown]
# **Scatter Plots**

# %%
scatter(df_short.index,df_short['age']);

# %% [markdown]
# **Histogram**

# %%
df_short2['fare'].hist(bins=10);

# %% [markdown]
# #### Multiple Plots
#
# If we run three separate scatter commands, one for each of the columns, Python will automatically place them in the same graph because they all share the same index (independent variable).

# %%
scatter(df_short.index,df_short['fare'],color='red');
scatter(df_short.index,df_short2['age']);

# %%
df_short2['fare'].plot();
df_short2['age'].plot();

# %% [markdown]
# However, if we had two different dataframes (distinct indices), and called sequential plots, we would get:

# %%
df_short['fare'].plot(color='blue');
df.plot();

# %% [markdown]
# ### More Advanced Plots
#
# While the methods of plotting we have seen so far are very handy for getting a quick insight into our data sets, Matplotlib allows us much finer control over graphing.  The code becomes a little more complicated, and has the following format:
#
# ```
# fig = plt.figure()  # declare a figure to a variable name
# plt.plot(x, y1, label='name1', color='colorname or hex code')
# plt.plot(x, y2, label='name2', color='colorname or hex code')  # repeat for as many things as you are plotting
# plt.xlabel('label for x', size=number)
# plt.ylabel('label for y', size=number)
# plt.legend()
# plt.grid()  # If this is included, a grid will be placed on your graph
# plt.title('Title')
# plt.show()
# ```

# %%
fig = plt.figure()
plt.plot(df_short.index,df_short['age'],label='age', color='green')
plt.plot(df_short.index,df_short['fare'],label='fare', color='blue')
plt.plot(df_short.index,df_short['Sex_num'],label='gender', color='pink')
plt.xlabel('Titanic', size=10)
plt.ylabel('Price',size=12)
plt.legend()
plt.title('Stock Prices',size=18)
plt.grid(b=True)
plt.show()

# %%
#lets do some more changes
fig = plt.figure()
plt.plot(df_short.index,df_short['fare'],label='fare', color='green')
plt.scatter(df_short.index,df_short['age'],label='age', color='blue')
plt.xlabel('Titanic', size=10)
plt.ylabel('Price',size=12)
plt.legend()
plt.title('Stock Prices',size=18)
plt.grid(b=True)
plt.show()

# %% [markdown]
# ### Subplots
#
# One nice feature of Matplotlib is the ability to output multiple graphs in the same image.  This is accomplished using  `gridspec` to create subplots. First, we declare the size of the subplots with `GridSpec(rows,columns)`, and then we plot our individual plots using `plt.subplot2grid()` with the following syntax:
#
# `GridSpec(number of rows, number of columns)`<br>
# `plt.subplot2grid((grid rows, grid columns), (plot row position, plot column position))`<br>
# `plt.plot(x,y)`

# %%
import matplotlib.gridspec as gridspec

fig = plt.figure()
# set up subplot grid; how many rows and columns
gridspec.GridSpec(2,1)

plt.subplot2grid((2,1), (0,0))  # (2,1) = total plot size, (0,0) = coordinates for *this* plot
plt.plot(df_short.index,df_short['age'],label='age', color='red')
plt.xlabel('Time', size=12)
plt.ylabel('Price',size=12)
plt.legend()
plt.xlim(df2.index[0],df2.index[-1])
plt.title('Titanic',size=18)
plt.grid()
fig.autofmt_xdate()

plt.subplot2grid((2,1), (1,0))
plt.plot(df_short.index,df_short['fare'],label='fare', color='blue')
plt.xlabel('', size=12)
plt.ylabel('Price',size=12)
plt.legend()
plt.xlim(df2.index[0],df2.index[-1])
plt.grid()
fig.autofmt_xdate()

plt.show()

# %% [markdown]
# You can find all the diffrent styles and examples for plots here: https://matplotlib.org/gallery/index.html

# %% [markdown]
# ## Exporting your data frame

# %% [markdown]
# Simlar to the import we can export our dataframe into csv and excel
#
# **CSV**
# df.to_csv('example',index=False)
#
# **Excel**
# df.to_excel('Excel_Sample.xlsx',sheet_name='Sheet1')
#
# **JSON**
# df.to_json('example',orient=None)

# %%
df_short.to_csv('clean.csv',index=False)

# %%
df_short.to_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

# %%
df_short.to_json('example.JSON',orient=None)
